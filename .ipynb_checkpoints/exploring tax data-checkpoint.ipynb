# %%
import numpy as np
import pandas as pd

# %%
tax_2010_path = 'data/irs_data/IRS County 2010.xls'
tax_2010 = pd.ExcelFile(tax_2010_path)
sheet_names = tax_2010.sheet_names

# %%
df = pd.read_excel(tax_2010_path, sheet_name='Sheet1', header=1)

# %%
df.head()
# Out:
#   Individual Income Tax Returns: \nSelected Income and Tax Items by State, \nand County, Tax Year 2010                                                                                                                                                                                                                                                                                                                                                                                                              \
# 0        [Money amounts are in thousands of dollars]
# 1                             State\nFIPS \ncode [1]
# 2                                                NaN
# 3                                                NaN
# 4                                                  0
#
#   Unnamed: 1                Unnamed: 2   Unnamed: 3         Unnamed: 4  \
# 0        NaN                       NaN          NaN                NaN
# ...

# %%
data_irs_2012 = pd.read_csv(r'data/irs_data/irs_count_2012.csv',encoding='latin-1')

# %%
data_irs_2012.describe()
# Out:
#          STATEFIPS   COUNTYFIPS  AGI_STUB            N1         MARS1  \
# count  3193.000000  3193.000000    3193.0  3.193000e+03  3.193000e+03
# mean     30.270279   102.116818       0.0  9.037388e+04  4.163534e+04
# std      15.155933   107.897455       0.0  5.485443e+05  2.559781e+05
# min       1.000000     0.000000       0.0  4.000000e+01  0.000000e+00
# 25%      18.000000    33.000000       0.0  4.700000e+03  1.880000e+03
# 50%      29.000000    77.000000       0.0  1.119000e+04  4.580000e+03
# 75%      45.000000   133.000000       0.0  3.150000e+04  1.357000e+04
# max      56.000000   840.000000       0.0  1.690603e+07  7.950890e+06
#
#               MARS2         MARS4          PREP            N2        NUMDEP  \
# count  3.193000e+03  3.193000e+03  3.193000e+03  3.193000e+03  3.193000e+03
# mean   3.345766e+04  1.357752e+04  5.052461e+04  1.792611e+05  6.105797e+04
# std    1.975137e+05  8.743620e+04  3.216625e+05  1.104286e+06  3.921778e+05
# ...

# %%
data_irs_2014 = pd.read_csv(r'data/irs_data/irs_count_2014.csv',encoding='latin-1')
data_irs_2016 = pd.read_csv(r'data/irs_data/irs_count_2016.csv',encoding='latin-1')
data_irs_2018 = pd.read_csv(r'data/irs_data/irs_count_2018.csv',encoding='latin-1')
data_irs_2020 = pd.read_csv(r'data/irs_data/irs_count_2020.csv',encoding='latin-1')

# %%
data_irs_2014.describe()
# Out:
#          STATEFIPS   COUNTYFIPS  AGI_STUB            N1         MARS1  \
# count  3192.000000  3192.000000    3192.0  3.192000e+03  3.192000e+03
# mean     30.263784   101.948935       0.0  9.213192e+04  4.311881e+04
# std      15.153863   107.629768       0.0  5.614940e+05  2.663945e+05
# min       1.000000     0.000000       0.0  3.000000e+01  0.000000e+00
# 25%      18.000000    33.000000       0.0  4.687500e+03  1.900000e+03
# 50%      29.000000    77.000000       0.0  1.134000e+04  4.630000e+03
# 75%      45.000000   133.000000       0.0  3.178750e+04  1.400250e+04
# max      56.000000   840.000000       0.0  1.741012e+07  8.344440e+06
#
#               MARS2         MARS4          PREP            N2        NUMDEP  \
# count  3.192000e+03  3.192000e+03  3.192000e+03  3.192000e+03  3.192000e+03
# mean   3.360547e+04  1.360760e+04  5.033366e+04  1.800856e+05  6.007572e+04
# std    1.994263e+05  8.742237e+04  3.236854e+05  1.112215e+06  3.859759e+05
# ...

# %%
data_irs_2016.describe()
# Out:
#          STATEFIPS   COUNTYFIPS  AGI_STUB            N1         MARS1  \
# count  3192.000000  3192.000000    3192.0  3.192000e+03  3.192000e+03
# mean     30.263784   101.948935       0.0  9.340985e+04  4.436169e+04
# std      15.153863   107.629768       0.0  5.704226e+05  2.750194e+05
# min       1.000000     0.000000       0.0  4.000000e+01  2.000000e+01
# 25%      18.000000    33.000000       0.0  4.630000e+03  1.870000e+03
# 50%      29.000000    77.000000       0.0  1.144000e+04  4.725000e+03
# 75%      45.000000   133.000000       0.0  3.193000e+04  1.421750e+04
# max      56.000000   840.000000       0.0  1.781612e+07  8.729140e+06
#
#               MARS2         MARS4          PREP            N2        NUMDEP  \
# count  3.192000e+03  3.192000e+03  3.192000e+03  3.192000e+03  3.192000e+03
# mean   3.374771e+04  1.342547e+04  4.996488e+04  1.801045e+05  5.877288e+04
# std    2.005704e+05  8.609472e+04  3.227115e+05  1.112049e+06  3.763101e+05
# ...

# %%
data_irs_2018.describe()
# Out:
#          STATEFIPS   COUNTYFIPS  AGI_STUB            N1         MARS1  \
# count  3192.000000  3192.000000    3192.0  3.192000e+03  3.192000e+03
# mean     30.263784   101.948935       0.0  9.563296e+04  4.603433e+04
# std      15.153863   107.629768       0.0  5.852795e+05  2.859995e+05
# min       1.000000     0.000000       0.0  5.000000e+01  2.000000e+01
# 25%      18.000000    33.000000       0.0  4.647500e+03  1.927500e+03
# 50%      29.000000    77.000000       0.0  1.159000e+04  4.920000e+03
# 75%      45.000000   133.000000       0.0  3.264750e+04  1.476750e+04
# max      56.000000   840.000000       0.0  1.817459e+07  9.053270e+06
#
#               MARS2         MARS4           ELF         CPREP          PREP  \
# count  3.192000e+03  3.192000e+03  3.192000e+03  3.192000e+03  3.192000e+03
# mean   3.417937e+04  1.339268e+04  8.584095e+04  5.414702e+03  5.049793e+04
# std    2.037314e+05  8.578128e+04  5.229993e+05  3.658436e+04  3.270951e+05
# ...

# %%
data_irs_2020.describe()
# Out:
#          STATEFIPS   COUNTYFIPS  AGI_STUB            N1         MARS1  \
# count  3193.000000  3193.000000    3193.0  3.193000e+03  3.193000e+03
# mean     30.254933   101.875666       0.0  1.022036e+05  5.212434e+04
# std      15.159743   107.580144       0.0  6.274921e+05  3.254716e+05
# min       1.000000     0.000000       0.0  4.000000e+01  2.000000e+01
# 25%      18.000000    33.000000       0.0  5.090000e+03  2.290000e+03
# 50%      29.000000    77.000000       0.0  1.253000e+04  5.780000e+03
# 75%      45.000000   133.000000       0.0  3.513000e+04  1.704000e+04
# max      56.000000   840.000000       0.0  1.955593e+07  1.039890e+07
#
#               MARS2         MARS4           ELF          CPREP          PREP  \
# count  3.193000e+03  3.193000e+03  3.193000e+03    3193.000000  3.193000e+03
# mean   3.438058e+04  1.326685e+04  9.427076e+04    3138.762919  5.340697e+04
# std    2.050055e+05  8.463639e+04  5.769148e+05   22322.160883  3.477058e+05
# ...

# %%
from docx import Document

# %%
def read_table_from_docx(docx_path):
    doc = Document(docx_path)
    tables = doc.tables

    data = {'Column1': [], 'Column2': [], 'Column3': []}  # Adjust column names accordingly

    for table in tables:
        for row in table.rows:
            columns = row.cells
            data['Column1'].append(columns[0].text)
            data['Column2'].append(columns[1].text)
            data['Column3'].append(columns[2].text)

    df = pd.DataFrame(data)
    return df

# %%
irs_table = r'data/irs_data/2020 irs table.docx'
df = read_table_from_docx(irs_table)

# %%
df
# Out:
#       Column1        Column2  \
# 0              VARIABLE NAME
# 1                  STATEFIPS
# 2                      STATE
# 3                   CBSACODE
# 4                  CBSATITLE
# ..        ...            ...
# 172    A11900         A11900
# 173    N11902         N11902
# 174    A11902         A11902
# 175    N12000         N12000
# 176    A12000         A12000
#
#                                                Column3
# 0                                        VARIABLE NAME
# 1                                            STATEFIPS
# 2                                                STATE
# 3                                             CBSACODE
# 4                                            CBSATITLE
# ..                                                 ...
# 172                          Total overpayments amount
# 173       Number of returns with overpayments refunded
# 174                Overpayments refunded amount [23]
# ...

# %%
data_irs_2020.head()
# Out:
#    STATEFIPS STATE  COUNTYFIPS      COUNTYNAME  AGI_STUB         N1  \
# 0          1    AL           0         Alabama         0  2246600.0
# 1          1    AL           1  Autauga County         0    26320.0
# 2          1    AL           3  Baldwin County         0   112470.0
# 3          1    AL           5  Barbour County         0    10760.0
# 4          1    AL           7     Bibb County         0     9330.0
#
#        MARS1     MARS2     MARS4        ELF  ...   N85300    A85300    N11901  \
# 0  1046200.0  763650.0  384290.0  2076330.0  ...  44390.0  184508.0  410620.0
# 1    11410.0   10130.0    4100.0    24310.0  ...    290.0     604.0    5020.0
# 2    49740.0   46300.0   13310.0   102570.0  ...   3070.0   10401.0   24830.0
# 3     5490.0    2790.0    2270.0     9340.0  ...    100.0     273.0    1480.0
# 4     4440.0    3170.0    1550.0     8180.0  ...     50.0     124.0    1310.0
#
#       A11901     N11900     A11900     N11902     A11902   N12000    A12000
# ...

# %%
OH_IRS_2020 = data_irs_2020.loc[data_irs_2020['STATE']=='OH']

# %%
OH_IRS_2020
# Out:
#       STATEFIPS STATE  COUNTYFIPS         COUNTYNAME  AGI_STUB         N1  \
# 2078         39    OH           0               Ohio         0  5897240.0
# 2079         39    OH           1       Adams County         0    11960.0
# 2080         39    OH           3       Allen County         0    50350.0
# 2081         39    OH           5     Ashland County         0    25640.0
# 2082         39    OH           7   Ashtabula County         0    47350.0
# ...         ...   ...         ...                ...       ...        ...
# 2162         39    OH         167  Washington County         0    29330.0
# 2163         39    OH         169       Wayne County         0    55620.0
# 2164         39    OH         171    Williams County         0    18760.0
# 2165         39    OH         173        Wood County         0    64310.0
# 2166         39    OH         175     Wyandot County         0    11350.0
#
#           MARS1      MARS2     MARS4        ELF  ...    N85300    A85300  \
# ...
