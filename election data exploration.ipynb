# %%
import numpy as np
import pandas as pd

# %%
all_elec_data = pd.read_csv('data/Election Results 1976-2022-house.csv')

# %%
all_elec_data.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic    office  \
# 0  1976  ALABAMA       AL           1         63        41  US HOUSE
# 1  1976  ALABAMA       AL           1         63        41  US HOUSE
# 2  1976  ALABAMA       AL           1         63        41  US HOUSE
# 3  1976  ALABAMA       AL           1         63        41  US HOUSE
# 4  1976  ALABAMA       AL           1         63        41  US HOUSE
#
#    district stage runoff  special                   candidate       party  \
# 0         1   GEN  False    False              BILL DAVENPORT    DEMOCRAT
# 1         1   GEN  False    False                JACK EDWARDS  REPUBLICAN
# 2         1   GEN  False    False                     WRITEIN         NaN
# 3         2   GEN  False    False             J CAROLE KEAHEY    DEMOCRAT
# 4         2   GEN  False    False  WILLIAM L "BILL" DICKINSON  REPUBLICAN
#
#    writein   mode  candidatevotes  totalvotes  unofficial   version  \
# ...

# %%
elec_2010 = all_elec_data.loc[all_elec_data['year']==2010]

# %%
elec_2010.head()
# Out:
#        year    state state_po  state_fips  state_cen  state_ic    office  \
# 22553  2010  ALABAMA       AL           1         63        41  US HOUSE
# 22554  2010  ALABAMA       AL           1         63        41  US HOUSE
# 22555  2010  ALABAMA       AL           1         63        41  US HOUSE
# 22556  2010  ALABAMA       AL           1         63        41  US HOUSE
# 22557  2010  ALABAMA       AL           1         63        41  US HOUSE
#
#        district stage runoff  special     candidate         party  writein  \
# 22553         1   GEN    NaN    False  DAVID WALTER  CONSTITUTION    False
# 22554         1   GEN    NaN    False     JO BONNER    REPUBLICAN    False
# 22555         1   GEN    NaN    False       WRITEIN           NaN     True
# 22556         2   GEN    NaN    False  BOBBY BRIGHT      DEMOCRAT    False
# 22557         2   GEN    NaN    False   MARTHA ROBY    REPUBLICAN    False
#
# ...

# %%
elec_2010['state_po'].unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI',
#        'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI',
#        'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC',
#        'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT',
#        'VT', 'VA', 'WA', 'WV', 'WI', 'WY'], dtype=object)

# %%
elec_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1500 entries, 22553 to 24052
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            1500 non-null   int64
#  1   state           1500 non-null   object
#  2   state_po        1500 non-null   object
#  3   state_fips      1500 non-null   int64
#  4   state_cen       1500 non-null   int64
#  5   state_ic        1500 non-null   int64
#  6   office          1500 non-null   object
#  7   district        1500 non-null   int64
#  8   stage           1500 non-null   object
#  9   runoff          0 non-null      object
#  10  special         1500 non-null   bool
#  11  candidate       1500 non-null   object
#  12  party           1311 non-null   object
#  13  writein         1500 non-null   bool
#  14  mode            1500 non-null   object
#  15  candidatevotes  1500 non-null   int64
#  16  totalvotes      1500 non-null   int64
# ...

# %%
elec_2010['stage'].unique()
# Out:
# array(['GEN'], dtype=object)

# %%
elec_2010['candidate'].nunique()
# Out:
# 1294

# %%
house_OH_elec_2010 = elec_2010.loc[elec_2010['state_po']=='OH']

# %%
house_cand_2010= pd.read_csv('house_cand_2010.csv')

# %%
house_cand_OH_2010 = house_cand_2010.loc[house_cand_2010['STATE ABBREVIATION']=="OH"]

# %%
house_cand_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1521 entries, 0 to 1520
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    1521 non-null   int64
#  1   STATE ABBREVIATION            1521 non-null   object
#  2   DISTRICT                      1521 non-null   object
#  3   CANDIDATE NAME (First)        1521 non-null   object
#  4   CANDIDATE NAME (Last)         1521 non-null   object
#  5   CANDIDATE NAME (Last, First)  1521 non-null   object
#  6   PARTY                         1521 non-null   object
#  7   INCUMBENT INDICATOR (I)       1521 non-null   int64
#  8   GENERAL                       1521 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 107.1+ KB

# %%
house_cand_OH_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 1080 to 1138
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    59 non-null     int64
#  1   STATE ABBREVIATION            59 non-null     object
#  2   DISTRICT                      59 non-null     object
#  3   CANDIDATE NAME (First)        59 non-null     object
#  4   CANDIDATE NAME (Last)         59 non-null     object
#  5   CANDIDATE NAME (Last, First)  59 non-null     object
#  6   PARTY                         59 non-null     object
#  7   INCUMBENT INDICATOR (I)       59 non-null     int64
#  8   GENERAL                       59 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 4.6+ KB

# %%
house_cand_OH_2010.head()
# Out:
#       Unnamed: 0 STATE ABBREVIATION DISTRICT CANDIDATE NAME (First)  \
# 1080        1237                 OH       01                  Steve
# 1081        1238                 OH       01                  Steve
# 1082        1239                 OH       01                    Jim
# 1083        1240                 OH       01                   Rich
# 1084        1241                 OH       02                   Jean
#
#      CANDIDATE NAME (Last) CANDIDATE NAME (Last, First) PARTY  \
# 1080                Chabot                Chabot, Steve   REP
# 1081              Driehaus              Driehaus, Steve   DEM
# 1082                 Berns                   Berns, Jim   LIB
# 1083             Stevenson              Stevenson, Rich   GRE
# 1084               Schmidt                Schmidt, Jean   REP
#
#       INCUMBENT INDICATOR (I) GENERAL
# 1080                        0   103770
# 1081                        1    92672
# 1082                        0     3076
# ...

# %%
house_OH_elec_2010.head()
# Out:
#        year state state_po  state_fips  state_cen  state_ic    office  \
# 23600  2010  OHIO       OH          39         31        24  US HOUSE
# 23601  2010  OHIO       OH          39         31        24  US HOUSE
# 23602  2010  OHIO       OH          39         31        24  US HOUSE
# 23603  2010  OHIO       OH          39         31        24  US HOUSE
# 23604  2010  OHIO       OH          39         31        24  US HOUSE
#
#        district stage runoff  special       candidate        party  writein  \
# 23600         1   GEN    NaN    False       JIM BERNS  LIBERTARIAN    False
# 23601         1   GEN    NaN    False  RICH STEVENSON        GREEN    False
# 23602         1   GEN    NaN    False    STEVE CHABOT   REPUBLICAN    False
# 23603         1   GEN    NaN    False  STEVE DRIEHAUS     DEMOCRAT    False
# 23604         2   GEN    NaN    False    JEAN SCHMIDT   REPUBLICAN    False
#
#         mode  candidatevotes  totalvotes  unofficial   version  fusion_ticket
# ...
